# %% [markdown]
# # Знакомство с pandas

# %%
import pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2 = pd.DataFrame({'A': 1.,
                     'B': pd.Timestamp('20130102'),
                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                     'D': np.array([3] * 4, dtype='int32'),
                     'E': pd.Categorical(["test", "train", "test", "train"]),
                     'F': 'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.372149 -0.340202  0.183519 -0.140156
# std    1.267120  0.848874  1.391247  0.646321
# min   -2.158528 -1.128042 -1.264417 -0.786693
# 25%   -1.307550 -0.912019 -1.020792 -0.614108
# 50%    0.115714 -0.552506  0.112378 -0.327432
# 75%    0.391693 -0.109481  1.060765  0.281489
# max    0.992491  1.185502  2.162399  0.825824

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228

# %% [markdown]
# ## Выборка

# %%
df['A']
# Out:
# 2013-01-01    0.992491
# 2013-01-02    0.412327
# 2013-01-03    0.329788
# 2013-01-04   -1.710613
# 2013-01-05   -2.158528
# 2013-01-06   -0.098361
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01  0.992491 -1.128042
# 2013-01-02  0.412327 -0.393596
# 2013-01-03  0.329788 -0.978886
# 2013-01-04 -1.710613  1.185502
# 2013-01-05 -2.158528 -0.014776
# 2013-01-06 -0.098361 -0.711415

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  0.412327 -0.393596
# 2013-01-03  0.329788 -0.978886
# 2013-01-04 -1.710613  1.185502

# %%
df.loc['20130102', ['A', 'B']]
# Out:
# A    0.412327
# B   -0.393596
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.iloc[3]
# Out:
# A   -1.710613
# B    1.185502
# C    1.162823
# D   -0.402228
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.710613  1.185502
# 2013-01-05 -2.158528 -0.014776

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  0.412327  2.162399
# 2013-01-03  0.329788 -1.264417
# 2013-01-05 -2.158528  0.754589

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.128042 -1.184445
# 2013-01-02 -0.393596  2.162399
# 2013-01-03 -0.978886 -1.264417
# 2013-01-04  1.185502  1.162823
# 2013-01-05 -0.014776  0.754589
# 2013-01-06 -0.711415 -0.529834

# %%
a = [1, 2, 3]
a[:]
# Out:
# [1, 2, 3]

# %%
a[1:]
# Out:
# [2, 3]

# %%
df.iloc[1, 1]
# Out:
# -0.3935958005288116

# %% [markdown]
# ## Выборка по условию

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.992491       NaN       NaN       NaN
# 2013-01-02  0.412327       NaN  2.162399       NaN
# 2013-01-03  0.329788       NaN       NaN  0.825824
# 2013-01-04       NaN  1.185502  1.162823       NaN
# 2013-01-05       NaN       NaN  0.754589       NaN
# 2013-01-06       NaN       NaN       NaN  0.459530

# %%
df2 = df.copy()

# %%
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637    one
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693    one
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824    two
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228  three
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735   four
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824   two
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735  four

# %%
df2['E'] = ['two', 'one', 'two', 'three', 'four', 'three']

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637   two
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824   two
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735  four

# %% [markdown]
# ## Установка новых колонок

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.992491 -1.128042 -1.184445 -0.252637  NaN
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693  1.0
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824  2.0
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228  3.0
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735  4.0
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530  5.0

# %%
df.at[dates[0], 'A'] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -1.128042 -1.184445 -0.252637  NaN
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693  1.0
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824  2.0
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228  3.0
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735  4.0
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530  5.0

# %%
df.iat[0, 1] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000 -1.184445 -0.252637  NaN
# 2013-01-02  0.412327 -0.393596  2.162399 -0.786693  1.0
# 2013-01-03  0.329788 -0.978886 -1.264417  0.825824  2.0
# 2013-01-04 -1.710613  1.185502  1.162823 -0.402228  3.0
# 2013-01-05 -2.158528 -0.014776  0.754589 -0.684735  4.0
# 2013-01-06 -0.098361 -0.711415 -0.529834  0.459530  5.0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.184445  5  NaN
# 2013-01-02  0.412327 -0.393596  2.162399  5  1.0
# 2013-01-03  0.329788 -0.978886 -1.264417  5  2.0
# 2013-01-04 -1.710613  1.185502  1.162823  5  3.0
# 2013-01-05 -2.158528 -0.014776  0.754589  5  4.0
# 2013-01-06 -0.098361 -0.711415 -0.529834  5  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.184445 -5  NaN
# 2013-01-02 -0.412327 -0.393596 -2.162399 -5 -1.0
# 2013-01-03 -0.329788 -0.978886 -1.264417 -5 -2.0
# 2013-01-04 -1.710613 -1.185502 -1.162823 -5 -3.0
# 2013-01-05 -2.158528 -0.014776 -0.754589 -5 -4.0
# 2013-01-06 -0.098361 -0.711415 -0.529834 -5 -5.0

# %% [markdown]
# ## Работа с пропусками

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1
# Out:
#                    A         B         C  D    F   E
# 2013-01-01  0.000000  0.000000 -1.184445  5  NaN NaN
# 2013-01-02  0.412327 -0.393596  2.162399  5  1.0 NaN
# 2013-01-03  0.329788 -0.978886 -1.264417  5  2.0 NaN
# 2013-01-04 -1.710613  1.185502  1.162823  5  3.0 NaN

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.184445  5  NaN  1.0
# 2013-01-02  0.412327 -0.393596  2.162399  5  1.0  1.0
# 2013-01-03  0.329788 -0.978886 -1.264417  5  2.0  NaN
# 2013-01-04 -1.710613  1.185502  1.162823  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  0.412327 -0.393596  2.162399  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.184445  5  5.0  1.0
# 2013-01-02  0.412327 -0.393596  2.162399  5  1.0  1.0
# 2013-01-03  0.329788 -0.978886 -1.264417  5  2.0  5.0
# 2013-01-04 -1.710613  1.185502  1.162823  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Статистика

# %%
df.mean()
# Out:
# A   -0.537564
# B   -0.152195
# C    0.183519
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    0.953889
# 2013-01-02    1.636226
# 2013-01-03    1.017297
# 2013-01-04    1.727542
# 2013-01-05    1.516257
# 2013-01-06    1.732078
# Freq: D, dtype: float64

# %% [markdown]
# ## Применение функций к данным

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.570856
# B    2.164388
# C    3.426817
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ## Слияние dataframes

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.378693 -0.996466  0.189991 -0.249201
# 1 -0.485677 -0.176478  0.199989 -0.087636
# 2 -1.139174  0.047663 -0.960343 -0.290734
# 3  0.487952  0.823737  0.648513  0.336600
# 4  1.015897 -0.818013  0.527543  1.614241
# 5 -0.724815  0.750254  1.332962 -1.673945
# 6  0.942007 -0.839891 -1.232417 -0.939759
# 7  0.042261 -0.725285 -2.421193 -0.738041
# 8 -0.185713 -0.804381  0.924251  0.881981
# 9  1.076027  0.196342  0.617937  0.574090

# %% [markdown]
# ## Конкатинация

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces[0]
# Out:
#           0         1         2         3
# 0  0.378693 -0.996466  0.189991 -0.249201
# 1 -0.485677 -0.176478  0.199989 -0.087636
# 2 -1.139174  0.047663 -0.960343 -0.290734

# %%
pieces[1]
# Out:
#           0         1         2         3
# 3  0.487952  0.823737  0.648513  0.336600
# 4  1.015897 -0.818013  0.527543  1.614241
# 5 -0.724815  0.750254  1.332962 -1.673945
# 6  0.942007 -0.839891 -1.232417 -0.939759

# %%
pieces[2]
# Out:
#           0         1         2         3
# 7  0.042261 -0.725285 -2.421193 -0.738041
# 8 -0.185713 -0.804381  0.924251  0.881981
# 9  1.076027  0.196342  0.617937  0.574090

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.378693 -0.996466  0.189991 -0.249201
# 1 -0.485677 -0.176478  0.199989 -0.087636
# 2 -1.139174  0.047663 -0.960343 -0.290734
# 3  0.487952  0.823737  0.648513  0.336600
# 4  1.015897 -0.818013  0.527543  1.614241
# 5 -0.724815  0.750254  1.332962 -1.673945
# 6  0.942007 -0.839891 -1.232417 -0.939759
# 7  0.042261 -0.725285 -2.421193 -0.738041
# 8 -0.185713 -0.804381  0.924251  0.881981
# 9  1.076027  0.196342  0.617937  0.574090

# %% [markdown]
# ## Конкатинация с условием

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Группировка

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                      'B': ['one', 'one', 'two', 'three',
                            'two', 'two', 'one', 'three'],
                      'C': np.random.randn(8),
                   'D': np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.822111 -1.243618
# 1  bar    one  0.065675 -0.686709
# 2  foo    two -0.448474  2.300606
# 3  bar  three -1.193451 -0.108085
# 4  foo    two  0.935995 -0.767338
# 5  bar    two  0.647338 -0.270661
# 6  foo    one  1.404384 -0.817280
# 7  foo  three -0.247357  1.736054

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.480437 -1.065454
# foo  0.822438  1.208424

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.065675 -0.686709
#     three -1.193451 -0.108085
#     two    0.647338 -0.270661
# foo one    0.582273 -2.060899
#     three -0.247357  1.736054
#     two    0.487522  1.533268

# %% [markdown]
# ## Отрисовка графиков

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.417027 -0.375934 -2.133342  0.122838
# 2000-01-02 -2.721767  0.335065  0.203664  0.187365
# 2000-01-03  0.633707  0.879521 -1.243042 -0.195209
# 2000-01-04 -0.302277 -0.590461  1.069156 -0.282270
# 2000-01-05  2.451834 -0.528272 -1.213788  0.249966
# 2000-01-06 -0.765752 -0.505722 -1.021666  0.758486
# 2000-01-07  0.878097 -0.043041  0.412436  0.482382
# 2000-01-08 -0.523470 -0.257189 -0.707330  0.974361
# 2000-01-09  0.147179  1.252557 -0.937346  0.230112
# 2000-01-10  0.646003  0.975141  1.639166  0.357695
# 2000-01-11  0.527536 -0.293721  1.935426 -0.603795
