# %% [markdown]
# # Решающие деревья

# %%
import pandas as pd

# %%
file_path = 'data/train.csv'

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
y = data.SalePrice

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
#          ...
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    394617
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    240000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# ...

# %%
features = ["BedroomAbvGr", "KitchenAbvGr", "YearBuilt", "LowQualFinSF", "GrLivArea"]

# %%
X = data[features]

# %%
X
# Out:
#       BedroomAbvGr  KitchenAbvGr  YearBuilt  LowQualFinSF  GrLivArea
# 0                3             1       2003             0       1710
# 1                3             1       1976             0       1262
# 2                3             1       2001             0       1786
# 3                3             1       1915             0       1717
# 4                4             1       2000             0       2198
# 5                1             1       1993             0       1362
# 6                3             1       2004             0       1694
# 7                3             1       1973             0       2090
# 8                2             2       1931             0       1774
# 9                2             2       1939             0       1077
# 10               3             1       1965             0       1040
# 11               4             1       2005             0       2324
# 12               2             1       1962             0        912
# ...

# %%
X.describe()
# Out:
#        BedroomAbvGr  KitchenAbvGr    YearBuilt  LowQualFinSF    GrLivArea
# count   1460.000000   1460.000000  1460.000000   1460.000000  1460.000000
# mean       2.866438      1.046575  1971.267808      5.844521  1515.463699
# std        0.815778      0.220338    30.202904     48.623081   525.480383
# min        0.000000      0.000000  1872.000000      0.000000   334.000000
# 25%        2.000000      1.000000  1954.000000      0.000000  1129.500000
# 50%        3.000000      1.000000  1973.000000      0.000000  1464.000000
# 75%        3.000000      1.000000  2000.000000      0.000000  1776.750000
# max        8.000000      3.000000  2010.000000    572.000000  5642.000000

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(random_state=1)

# %%
model
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1, splitter='best')

# %%
model.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=1, splitter='best')

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(model.predict(X.head()))
# Out:
# Making predictions for the following 5 houses:
#    BedroomAbvGr  KitchenAbvGr  YearBuilt  LowQualFinSF  GrLivArea
# 0             3             1       2003             0       1710
# 1             3             1       1976             0       1262
# 2             3             1       2001             0       1786
# 3             3             1       1915             0       1717
# 4             4             1       2000             0       2198
# The predictions are
# [208500. 181500. 223500. 140000. 250000.]

# %%
y[0:5]
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
file_test_path = 'data/test.csv'

# %%
data = pd.read_csv(file_test_path)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5     1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7     1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8     1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9     1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10    1471         120       RH         26.0     5858   Pave   NaN      IR1
# ...

# %%
features = ["BedroomAbvGr", "KitchenAbvGr", "YearBuilt", "LowQualFinSF", "GrLivArea"]

# %%
X_test = data[features]

# %%
X_test
# Out:
#       BedroomAbvGr  KitchenAbvGr  YearBuilt  LowQualFinSF  GrLivArea
# 0                2             1       1961             0        896
# 1                3             1       1958             0       1329
# 2                3             1       1997             0       1629
# 3                3             1       1998             0       1604
# 4                2             1       1992             0       1280
# 5                3             1       1993             0       1655
# 6                3             1       1992             0       1187
# 7                3             1       1998             0       1465
# 8                2             1       1990             0       1341
# 9                2             1       1970             0        882
# 10               2             1       1999             0       1337
# 11               2             1       1971             0        987
# 12               3             1       1971             0       1092
# ...

# %%
model.predict(X_test)
# Out:
# array([151500., 139000., 176500., ..., 128950., 147000., 239500.])

# %%
y_test = [model.predict(X_test)]

# %%
y_test
# Out:
# [array([151500., 139000., 176500., ..., 128950., 147000., 239500.])]

# %%
y_test[0]
# Out:
# array([151500., 139000., 176500., ..., 128950., 147000., 239500.])

# %%
y_test[0][0]
# Out:
# 151500.0

# %%
id = data["Id"]

# %%
id
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
# 5       1466
# 6       1467
# 7       1468
# 8       1469
# 9       1470
# 10      1471
# 11      1472
# 12      1473
# 13      1474
# 14      1475
# 15      1476
# 16      1477
# 17      1478
# 18      1479
# 19      1480
# 20      1481
# 21      1482
# 22      1483
# 23      1484
# 24      1485
# 25      1486
# 26      1487
# 27      1488
# 28      1489
# 29      1490
#         ...
# 1429    2890
# 1430    2891
# 1431    2892
# 1432    2893
# 1433    2894
# 1434    2895
# 1435    2896
# 1436    2897
# 1437    2898
# 1438    2899
# 1439    2900
# 1440    2901
# 1441    2902
# 1442    2903
# 1443    2904
# 1444    2905
# 1445    2906
# 1446    2907
# 1447    2908
# 1448    2909
# 1449    2910
# 1450    2911
# 1451    2912
# 1452    2913
# 1453    2914
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
type(id)
# Out:
# pandas.core.series.Series

# %%
for idx, i in enumerate(id):
    print(i, y_test[0][idx])
# Out:
# 1461 151500.0
# 1462 139000.0
# 1463 176500.0
# 1464 181000.0
# 1465 179200.0
# 1466 193500.0
# 1467 173000.0
# 1468 177000.0
# 1469 180000.0
# 1470 97000.0
# 1471 167250.0
# 1472 87450.0
# 1473 88000.0
# 1474 148500.0
# 1475 124900.0
# 1476 451950.0
# 1477 215200.0
# 1478 200000.0
# 1479 319000.0
# 1480 412500.0
# 1481 228500.0
# 1482 202500.0
# 1483 169990.0
# 1484 84500.0
# 1485 181750.0
# 1486 225000.0
# 1487 267000.0
# 1488 277500.0
# 1489 208300.0
# 1490 215000.0
# 1491 165400.0
# 1492 118400.0
# 1493 180000.0
# 1494 265000.0
# 1495 222000.0
# 1496 265900.0
# 1497 266000.0
# 1498 151000.0
# 1499 151000.0
# 1500 194000.0
# 1501 168500.0
# 1502 138000.0
# 1503 392000.0
# 1504 248000.0
# 1505 221000.0
# 1506 201800.0
# 1507 290000.0
# 1508 187000.0
# 1509 163500.0
# 1510 135000.0
# 1511 143000.0
# 1512 185750.0
# 1513 228950.0
# 1514 125000.0
# 1515 244400.0
# 1516 140000.0
# 1517 155000.0
# 1518 100000.0
# 1519 226000.0
# 1520 143000.0
# 1521 128950.0
# 1522 140000.0
# ...

# %%
f = open("s.csv", "w")

# %%
f.close()

# %%
f = open("s.csv", "w")
f.write("Id,SalePrice"+"\n")
for idx, i in enumerate(id):
    f.write(f'{i},{y_test[0][idx]}\n')
f.close()
